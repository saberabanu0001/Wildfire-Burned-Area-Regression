# %% [markdown]
# # Phase 6 — Evaluation & Results

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT))

import pandas as pd
from IPython.display import Image, display

results_dir = ROOT / "artifacts" / "results"
plots_dir = ROOT / "artifacts" / "plots"

comparison = pd.read_csv(results_dir / "comparison.csv")
display(comparison)

for plot in ["baseline_predictions.png", "shap_predictions.png", "pso_predictions.png", "shap_summary.png", "pso_convergence.png"]:
    path = plots_dir / plot
    if path.exists():
        print(plot)
        display(Image(filename=str(path)))
