# %% [markdown]
# # Phase 2 — Preprocessing
#
# log1p target, one-hot encoding, MinMaxScaler, 70/15/15 split.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT))

from src.data import prepare_data

splits = prepare_data(str(ROOT / "config.yaml"))
print(f"Train: {len(splits['y_train'])}, Val: {len(splits['y_val'])}, Test: {len(splits['y_test'])}")
print(f"Features after one-hot: {len(splits['feature_cols'])}")
