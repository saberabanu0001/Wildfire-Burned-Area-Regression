# %% [markdown]
# # Phase 4 — SHAP Feature Selection

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT))

from src.data import prepare_data
from src.shap_selection import run_shap_selection

splits = prepare_data(str(ROOT / "config.yaml"))
out = run_shap_selection(splits)
print("Dropped:", out["dropped_features"])
print("Test metrics:", out["train_result"]["test_metrics"])
