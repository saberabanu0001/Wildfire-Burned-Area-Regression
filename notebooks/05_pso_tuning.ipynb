# %% [markdown]
# # Phase 5 — PSO Hyperparameter Tuning

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT))

from src.data import prepare_data
from src.pso_tune import run_pso_tuning
from src.shap_selection import run_shap_selection

splits = prepare_data(str(ROOT / "config.yaml"))
shap_out = run_shap_selection(splits)
pso_out = run_pso_tuning(splits, feature_splits=shap_out["reduced_splits"])
print("Best hyperparameters:", pso_out["pso_result"]["best_hyperparameters"])
print("Test metrics:", pso_out["train_result"]["test_metrics"])
